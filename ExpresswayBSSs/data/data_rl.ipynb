# %% [markdown]
# #### 生成RL环境的instance
# 1. 先选择小规模的测试 3s 4e
# 2. 中规模检查效果 6s 8e
# 3. 大规模论文使用 11s 13e
#
# 在RL训练阶段：
# 不需要和gurobi交互，只是在实现阶段交互就行。不考虑预约用户不到的情况。
# 1. 对于预约需求到每个站点的映射 -- 生成，实际就是这样来的。
# 2. 对于随机需求，只知道未来均值。和当前的需求。
#
# 在RL测试阶段：和MPC框架交互。
#
# xxx

# %% [markdown]
# #### 小规模测试数据生成
# 1. 预约需求占比epsilon
# 2. 随机需求的数据从蔚来APP上找
